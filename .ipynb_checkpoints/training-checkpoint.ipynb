# %%
import keras
import tensorflow
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.models import Sequential, Model 
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras_video import VideoFrameGenerator

import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
import keras_metrics as km
from keras import metrics
import glob
 
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import classification_report

# %%
data_dir = "./videodata/"
filename = "ConvLSTM_model.h5"
h, w = 140, 90
time_steps = 10

#classes = ["Backstroke", "Breaststroke", "Freestyle"]
classes = [i.split(os.path.sep)[1] for i in glob.glob('./videodata/*')]
classes.sort()
#print(classes)

#glob_pattern='./videodata/{classname}/*.avi'

#data_aug = ImageDataGenerator(
#    zoom_range = [0.6, 1.2],
#    horizontal_flip = True,
#    rotation_range = 180,
#    width_shift_range = 0,
#    height_shift_range = 0)

#train = VideoFrameGenerator(
#    classes=classes, 
#    glob_pattern=glob_pattern,
#    nb_frames=time_steps,
#    split = 0.3, 
#    shuffle = True,
#    batch_size = 1,
#    target_shape = (w, h),
#    nb_channel = 3,
#    transformation=data_aug,
#    use_frame_cache=True)
#valid = train.get_validation_generator()

# %%
# Zoom in
def cv2_clipped_zoom(img, zoom_factor):
    """
    Center zoom in/out of the given image and returning an enlarged/shrinked view of 
    the image without changing dimensions
    Args:
        img : Image array
        zoom_factor : amount of zoom as a ratio (0 to Inf)
    """
    height, width = img.shape[:2] # It's also the final desired shape
    new_height, new_width = int(height * zoom_factor), int(width * zoom_factor)

    ### Crop only the part that will remain in the result (more efficient)
    # Centered bbox of the final desired size in resized (larger/smaller) image coordinates
    y1, x1 = max(0, new_height - height) // 2, max(0, new_width - width) // 2
    y2, x2 = y1 + height, x1 + width
    bbox = np.array([y1,x1,y2,x2])
    # Map back to original image coordinates
    bbox = (bbox / zoom_factor).astype(np.int)
    y1, x1, y2, x2 = bbox
    cropped_img = img[y1:y2, x1:x2]

    # Handle padding when downscaling
    resize_height, resize_width = min(new_height, height), min(new_width, width)
    pad_height1, pad_width1 = (height - resize_height) // 2, (width - resize_width) //2
    pad_height2, pad_width2 = (height - resize_height) - pad_height1, (width - resize_width) - pad_width1
    pad_spec = [(pad_height1, pad_height2), (pad_width1, pad_width2)] + [(0,0)] * (img.ndim - 2)

    result = cv2.resize(cropped_img, (resize_width, resize_height))
    result = np.pad(result, pad_spec, mode='constant')
    assert result.shape[0] == height and result.shape[1] == width
    return result

#  Creating frames from videos
def frames_extraction(video_path):
    frames = []
     
    video = cv2.VideoCapture(video_path)
    # Used as counter variable 
    count = 1
    while count <= time_steps:
        ret, img = video.read() 
        if ret:
            img = cv2.resize(img, (w, h))
            #img = cv2_clipped_zoom(img, 1.2)
            
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            #img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            
            frames.append(img)
            count += 1
        else:
            print("Defected frame")
            break
    #return frames
    rotate_frames = []
    zoom_frames = []
    for img in frames:
        rimg = cv2.rotate(img, cv2.ROTATE_180)
        rotate_frames.append(rimg)
    for img in frames:
        zimg = cv2_clipped_zoom(img, 1.5)
        zoom_frames.append(zimg)

        
    return frames, rotate_frames, zoom_frames

def create_data(input_dir):
    X = []
    Y = []
     
    classes_list = os.listdir(input_dir)
    print(classes_list)
    for c in classes_list:
        print(c)
        files_list = os.listdir(os.path.join(input_dir, c))
        for f in files_list:
            frames, rotate_frames, zoom_frames = frames_extraction(os.path.join(os.path.join(input_dir, c), f))
            #frames = frames_extraction(os.path.join(os.path.join(input_dir, c), f))
            
            #if len(frames) == time_steps:
            #    X.append(frames)
            #    y = [0]*len(classes)
            #    y[classes.index(c)] = 1
            #    Y.append(y)
                
            if len(frames) == time_steps and len(rotate_frames) == time_steps and len(zoom_frames) == time_steps:
                X.append(frames)
                y = [0]*len(classes)
                y[classes.index(c)] = 1
                Y.append(y)
                
                X.append(rotate_frames)
                y = [0]*len(classes)
                y[classes.index(c)] = 1
                Y.append(y)
                
                X.append(zoom_frames)
                y = [0]*len(classes)
                y[classes.index(c)] = 1
                Y.append(y)
                
    X = np.asarray(X)
    Y = np.asarray(Y)
    return X, Y

X, Y = create_data(data_dir)
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.5, shuffle=True)
X = np.concatenate((X_train, X_test))
Y = np.concatenate((y_train, y_test))
# Out:
# ['Backstroke', 'Breaststroke', 'Freestyle']
# Backstroke
# Breaststroke
# Freestyle

# %%
import matplotlib.pyplot as plt

print(X.shape)
#X_train = np.expand_dims(X_train, axis=-1)
#X_test = np.expand_dims(X_test, axis=-1)
#y_train = np.expand_dims(y_train, axis=-1)
#y_test = np.expand_dims(y_test, axis=-1)

#print(X_train.shape)
#img = cv2_clipped_zoom(X[2][8], 1.5)
#plt.imshow(img)

#plt.plot()

print(len(X))
print(len(Y))
# Out:
# (381, 10, 140, 90, 3)
# 381
# 381

# %%
model = Sequential()
# input_shape: (time_steps, map_height, map_width, channels)
model.add(ConvLSTM2D(filters = 32, kernel_size = (3, 3), input_shape = (time_steps, h, w, 3), return_sequences = True))
model.add(ConvLSTM2D(filters = 32, kernel_size = (3, 3), return_sequences = True))
model.add(BatchNormalization())
#model.add(LeakyReLU(alpha=0.2))
model.add(Dropout(0.2))


model.add(ConvLSTM2D(filters = 32, kernel_size = (3, 3), return_sequences = True))
model.add(ConvLSTM2D(filters = 32, kernel_size = (3, 3), return_sequences = True))
model.add(BatchNormalization())
#model.add(LeakyReLU(alpha=0.2))
model.add(MaxPooling3D((1, 2, 2)))
model.add(Dropout(0.2))

model.add(ConvLSTM2D(filters = 32, kernel_size = (3, 3), return_sequences = True))
model.add(ConvLSTM2D(filters = 32, kernel_size = (3, 3), return_sequences = True))
model.add(BatchNormalization())
#model.add(LeakyReLU(alpha=0.2))
#model.add(AveragePooling3D((1, 2, 2)))
model.add(Dropout(0.2))

model.add(ConvLSTM2D(filters = 32, kernel_size = (3, 3), return_sequences = True))
model.add(ConvLSTM2D(filters = 32, kernel_size = (3, 3), return_sequences = False))
model.add(BatchNormalization())
#model.add(LeakyReLU(alpha=0.2))
model.add(AveragePooling2D((2, 2)))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(3, activation='softmax'))
model.summary()

opt = Adam(lr=1e-6)
#opt = SGD(lr=0.0001)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=["accuracy"])

checkpoint = ModelCheckpoint(filepath=filename,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True)

stop = EarlyStopping(monitor='loss', patience = 10,
                      verbose=0, mode='auto', baseline=None, 
                      restore_best_weights=False)
callbacks = [checkpoint, stop]

history = model.fit(x = X, y = Y, epochs = 1000, batch_size = 4, shuffle=True, validation_split=0.2, callbacks=callbacks)
#history = model.fit(train, validation_data=valid, verbose=1, epochs=50, shuffle=True, callbacks=callbacks)
print("Training finished.")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d_16 (ConvLSTM2D) (None, 10, 138, 88, 32)   40448
# _________________________________________________________________
# conv_lst_m2d_17 (ConvLSTM2D) (None, 10, 136, 86, 32)   73856
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 10, 136, 86, 32)   128
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 10, 136, 86, 32)   0
# _________________________________________________________________
# conv_lst_m2d_18 (ConvLSTM2D) (None, 10, 134, 84, 32)   73856
# _________________________________________________________________
# conv_lst_m2d_19 (ConvLSTM2D) (None, 10, 132, 82, 32)   73856
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 10, 132, 82, 32)   128
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 10, 66, 41, 32)    0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 10, 66, 41, 32)    0
# _________________________________________________________________
# conv_lst_m2d_20 (ConvLSTM2D) (None, 10, 64, 39, 32)    73856
# _________________________________________________________________
# conv_lst_m2d_21 (ConvLSTM2D) (None, 10, 62, 37, 32)    73856
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 10, 62, 37, 32)    128
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 10, 62, 37, 32)    0
# _________________________________________________________________
# conv_lst_m2d_22 (ConvLSTM2D) (None, 10, 60, 35, 32)    73856
# _________________________________________________________________
# conv_lst_m2d_23 (ConvLSTM2D) (None, 58, 33, 32)        73856
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 58, 33, 32)        128
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 29, 16, 32)        0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 29, 16, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 14848)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                475168
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 1,034,275
# Trainable params: 1,034,019
# Non-trainable params: 256
# _________________________________________________________________
# Epoch 1/1000
# 76/76 [==============================] - ETA: 0s - loss: 1.3109 - accuracy: 0.3289
# Epoch 00001: val_loss improved from inf to 1.09970, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 39s 507ms/step - loss: 1.3109 - accuracy: 0.3289 - val_loss: 1.0997 - val_accuracy: 0.3117
# Epoch 2/1000
# 76/76 [==============================] - ETA: 0s - loss: 1.3009 - accuracy: 0.3520
# Epoch 00002: val_loss did not improve from 1.09970
# 76/76 [==============================] - 37s 485ms/step - loss: 1.3009 - accuracy: 0.3520 - val_loss: 1.1008 - val_accuracy: 0.3117
# Epoch 3/1000
# 76/76 [==============================] - ETA: 0s - loss: 1.2551 - accuracy: 0.3191
# Epoch 00003: val_loss did not improve from 1.09970
# 76/76 [==============================] - 38s 499ms/step - loss: 1.2551 - accuracy: 0.3191 - val_loss: 1.1008 - val_accuracy: 0.3117
# Epoch 4/1000
# 76/76 [==============================] - ETA: 0s - loss: 1.1749 - accuracy: 0.4243
# Epoch 00004: val_loss improved from 1.09970 to 1.09550, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 40s 522ms/step - loss: 1.1749 - accuracy: 0.4243 - val_loss: 1.0955 - val_accuracy: 0.3117
# Epoch 5/1000
# 76/76 [==============================] - ETA: 0s - loss: 1.1263 - accuracy: 0.3882
# Epoch 00005: val_loss improved from 1.09550 to 1.07667, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 40s 525ms/step - loss: 1.1263 - accuracy: 0.3882 - val_loss: 1.0767 - val_accuracy: 0.3247
# Epoch 6/1000
# 76/76 [==============================] - ETA: 0s - loss: 1.0701 - accuracy: 0.4375
# Epoch 00006: val_loss improved from 1.07667 to 1.04665, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 40s 527ms/step - loss: 1.0701 - accuracy: 0.4375 - val_loss: 1.0466 - val_accuracy: 0.3636
# Epoch 7/1000
# 76/76 [==============================] - ETA: 0s - loss: 1.0596 - accuracy: 0.4770
# Epoch 00007: val_loss improved from 1.04665 to 1.03436, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 40s 520ms/step - loss: 1.0596 - accuracy: 0.4770 - val_loss: 1.0344 - val_accuracy: 0.4156
# Epoch 8/1000
# 76/76 [==============================] - ETA: 0s - loss: 1.0332 - accuracy: 0.4671
# Epoch 00008: val_loss improved from 1.03436 to 1.00958, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 39s 515ms/step - loss: 1.0332 - accuracy: 0.4671 - val_loss: 1.0096 - val_accuracy: 0.4286
# Epoch 9/1000
# 76/76 [==============================] - ETA: 0s - loss: 1.0376 - accuracy: 0.4638
# Epoch 00009: val_loss improved from 1.00958 to 0.98877, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 40s 527ms/step - loss: 1.0376 - accuracy: 0.4638 - val_loss: 0.9888 - val_accuracy: 0.4545
# Epoch 10/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.9931 - accuracy: 0.5164
# Epoch 00010: val_loss improved from 0.98877 to 0.96754, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 39s
1000
# 76/76 [==============================] - ETA: 0s - loss: 0.4647 - accuracy: 0.8059
# Epoch 00070: val_loss improved from 0.40102 to 0.38837, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 494ms/step - loss: 0.4647 - accuracy: 0.8059 - val_loss: 0.3884 - val_accuracy: 0.7922
# Epoch 71/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.5026 - accuracy: 0.7961
# Epoch 00071: val_loss improved from 0.38837 to 0.36624, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 37s 493ms/step - loss: 0.5026 - accuracy: 0.7961 - val_loss: 0.3662 - val_accuracy: 0.8312
# Epoch 72/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.5211 - accuracy: 0.7566
# Epoch 00072: val_loss improved from 0.36624 to 0.35708, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 37s 491ms/step - loss: 0.5211 - accuracy: 0.7566 - val_loss: 0.3571 - val_accuracy: 0.8701
# Epoch 73/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.4879 - accuracy: 0.7961
# Epoch 00073: val_loss improved from 0.35708 to 0.35142, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 37s 491ms/step - loss: 0.4879 - accuracy: 0.7961 - val_loss: 0.3514 - val_accuracy: 0.8831
# Epoch 74/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.4458 - accuracy: 0.8322
# Epoch 00074: val_loss improved from 0.35142 to 0.34800, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 37s 492ms/step - loss: 0.4458 - accuracy: 0.8322 - val_loss: 0.3480 - val_accuracy: 0.8701
# Epoch 75/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.4887 - accuracy: 0.7862
# Epoch 00075: val_loss improved from 0.34800 to 0.34458, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 37s 491ms/step - loss: 0.4887 - accuracy: 0.7862 - val_loss: 0.3446 - val_accuracy: 0.8701
# Epoch 76/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.4390 - accuracy: 0.8421
# Epoch 00076: val_loss improved from 0.34458 to 0.34137, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 37s 492ms/step - loss: 0.4390 - accuracy: 0.8421 - val_loss: 0.3414 - val_accuracy: 0.8701
# Epoch 77/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.4803 - accuracy: 0.7829
# Epoch 00077: val_loss improved from 0.34137 to 0.32504, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 501ms/step - loss: 0.4803 - accuracy: 0.7829 - val_loss: 0.3250 - val_accuracy: 0.9091
# Epoch 78/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.4500 - accuracy: 0.7829
# Epoch 00078: val_loss improved from 0.32504 to 0.32081, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 499ms/step - loss: 0.4500 - accuracy: 0.7829 - val_loss: 0.3208 - val_accuracy: 0.9091
# Epoch 79/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.4576 - accuracy: 0.8224
# Epoch 00079: val_loss improved from 0.32081 to 0.30555, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 502ms/step - loss: 0.4576 - accuracy: 0.8224 - val_loss: 0.3055 - val_accuracy: 0.9091
# Epoch 80/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3999 - accuracy: 0.8553
# Epoch 00080: val_loss improved from 0.30555 to 0.29491, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 496ms/step - loss: 0.3999 - accuracy: 0.8553 - val_loss: 0.2949 - val_accuracy: 0.9221
# Epoch 81/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.4474 - accuracy: 0.8191
# Epoch 00081: val_loss did not improve from 0.29491
# 76/76 [==============================] - 37s 490ms/step - loss: 0.4474 - accuracy: 0.8191 - val_loss: 0.2984 - val_accuracy: 0.9091
# Epoch 82/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.4255 - accuracy: 0.8289
# Epoch 00082: val_loss improved from 0.29491 to 0.27856, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 498ms/step - loss: 0.4255 - accuracy: 0.8289 - val_loss: 0.2786 - val_accuracy: 0.9221
# Epoch 83/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.4757 - accuracy: 0.8059
# Epoch 00083: val_loss did not improve from 0.27856
# 76/76 [==============================] - 37s 492ms/step - loss: 0.4757 - accuracy: 0.8059 - val_loss: 0.2826 - val_accuracy: 0.9221
# Epoch 84/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3882 - accuracy: 0.8520
# Epoch 00084: val_loss did not improve from 0.27856
# 76/76 [==============================] - 37s 490ms/step - loss: 0.3882 - accuracy: 0.8520 - val_loss: 0.2805 - val_accuracy: 0.9221
# Epoch 85/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.4627 - accuracy: 0.7928
# Epoch 00085: val_loss improved from 0.27856 to 0.27152, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 497ms/step - loss: 0.4627 - accuracy: 0.7928 - val_loss: 0.2715 - val_accuracy: 0.9221
# Epoch 86/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.4356 - accuracy: 0.8158
# Epoch 00086: val_loss improved from 0.27152 to 0.26459, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 497ms/step - loss: 0.4356 - accuracy: 0.8158 - val_loss: 0.2646 - val_accuracy: 0.9221
# Epoch 87/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.4081 - accuracy: 0.8388
# Epoch 00087: val_loss improved from 0.26459 to 0.25760, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 494ms/step - loss: 0.4081 - accuracy: 0.8388 - val_loss: 0.2576 - val_accuracy: 0.9221
# Epoch 88/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.4160 - accuracy: 0.8388
# Epoch 00088: val_loss improved from 0.25760 to 0.24755, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 494ms/step - loss: 0.4160 - accuracy: 0.8388 - val_loss: 0.2476 - val_accuracy: 0.9351
# Epoch 89/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.4003 - accuracy: 0.8717
# Epoch 00089: val_loss improved from 0.24755 to 0.22998, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 496ms/step - loss: 0.4003 - accuracy: 0.8717 - val_loss: 0.2300 - val_accuracy: 0.9481
# Epoch 90/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.4045 - accuracy: 0.8553
# Epoch 00090: val_loss did not improve from 0.22998
# 76/76 [==============================] - 37s 488ms/step - loss: 0.4045 - accuracy: 0.8553 - val_loss: 0.2332 - val_accuracy: 0.9481
# Epoch 91/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3978 - accuracy: 0.8257
# Epoch 00091: val_loss improved from 0.22998 to 0.22939, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 495ms/step - loss: 0.3978 - accuracy: 0.8257 - val_loss: 0.2294 - val_accuracy: 0.9481
# Epoch 92/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.4248 - accuracy: 0.8125
# Epoch 00092: val_loss improved from 0.22939 to 0.22708, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 496ms/step - loss: 0.4248 - accuracy: 0.8125 - val_loss: 0.2271 - val_accuracy: 0.9351
# Epoch 93/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.4430 - accuracy: 0.8421
# Epoch 00093: val_loss improved from 0.22708 to 0.21785, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 495ms/step - loss: 0.4430 - accuracy: 0.8421 - val_loss: 0.2179 - val_accuracy: 0.9481
# Epoch 94/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3796 - accuracy: 0.8586
# Epoch 00094: val_loss improved from 0.21785 to 0.20206, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 494ms/step - loss: 0.3796 - accuracy: 0.8586 - val_loss: 0.2021 - val_accuracy: 0.9610
# Epoch 95/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3375 - accuracy: 0.8651
# Epoch 00095: val_loss did not improve from 0.20206
# 76/76 [==============================] - 37s 492ms/step - loss: 0.3375 - accuracy: 0.8651 - val_loss: 0.2026 - val_accuracy: 0.9610
# Epoch 96/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3821 - accuracy: 0.8322
# Epoch 00096: val_loss improved from 0.20206 to 0.19818, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 37s 491ms/step - loss: 0.3821 - accuracy: 0.8322 - val_loss: 0.1982 - val_accuracy: 0.9610
# Epoch 97/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3641 - accuracy: 0.8717
# Epoch 00097: val_loss did not improve from 0.19818
# 76/76 [==============================] - 37s 491ms/step - loss: 0.3641 - accuracy: 0.8717 - val_loss: 0.1998 - val_accuracy: 0.9610
# Epoch 98/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3121 - accuracy: 0.8980
# Epoch 00098: val_loss improved from 0.19818 to 0.19216, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 499ms/step - loss: 0.3121 - accuracy: 0.8980 - val_loss: 0.1922 - val_accuracy: 0.9610
# Epoch 99/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3329 - accuracy: 0.8849
# Epoch 00099: val_loss improved from 0.19216 to 0.17799, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 504ms/step - loss: 0.3329 - accuracy: 0.8849 - val_loss: 0.1780 - val_accuracy: 0.9610
# Epoch 100/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3314 - accuracy: 0.8618
# Epoch 00100: val_loss did not improve from 0.17799
# 76/76 [==============================] - 39s 519ms/step - loss: 0.3314 - accuracy: 0.8618 - val_loss: 0.1819 - val_accuracy: 0.9610
# Epoch 101/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3973 - accuracy: 0.8388
# Epoch 00101: val_loss improved from 0.17799 to 0.16689, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 39s 517ms/step - loss: 0.3973 - accuracy: 0.8388 - val_loss: 0.1669 - val_accuracy: 0.9610
# Epoch 102/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3700 - accuracy: 0.8586
# Epoch 00102: val_loss did not improve from 0.16689
# 76/76 [==============================] - 37s 486ms/step - loss: 0.3700 - accuracy: 0.8586 - val_loss: 0.1703 - val_accuracy: 0.9610
# Epoch 103/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3605 - accuracy: 0.8717
# Epoch 00103: val_loss improved from 0.16689 to 0.15620, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 37s 490ms/step - loss: 0.3605 - accuracy: 0.8717 - val_loss: 0.1562 - val_accuracy: 0.9610
# Epoch 104/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.2915 - accuracy: 0.9013
# Epoch 00104: val_loss improved from 0.15620 to 0.15148, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 499ms/step - loss: 0.2915 - accuracy: 0.9013 - val_loss: 0.1515 - val_accuracy: 0.9610
# Epoch 105/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3682 - accuracy: 0.8586
# Epoch 00105: val_loss did not improve from 0.15148
# 76/76 [==============================] - 37s 491ms/step - loss: 0.3682 - accuracy: 0.8586 - val_loss: 0.1625 - val_accuracy: 0.9610
# Epoch 106/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3859 - accuracy: 0.8421
# Epoch 00106: val_loss did not improve from 0.15148
# 76/76 [==============================] - 38s 506ms/step - loss: 0.3859 - accuracy: 0.8421 - val_loss: 0.1721 - val_accuracy: 0.9610
# Epoch 107/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3497 - accuracy: 0.8487
# Epoch 00107: val_loss did not improve from 0.15148
# 76/76 [==============================] - 39s 511ms/step - loss: 0.3497 - accuracy: 0.8487 - val_loss: 0.1619 - val_accuracy: 0.9610
# Epoch 108/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3157 - accuracy: 0.9013
# Epoch 00108: val_loss improved from 0.15148 to 0.14974, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 502ms/step - loss: 0.3157 - accuracy: 0.9013 - val_loss: 0.1497 - val_accuracy: 0.9610
# Epoch 109/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3370 - accuracy: 0.8618
# Epoch 00109: val_loss improved from 0.14974 to 0.14458, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 495ms/step - loss: 0.3370 - accuracy: 0.8618 - val_loss: 0.1446 - val_accuracy: 0.9610
# Epoch 110/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3559 - accuracy: 0.8454
# Epoch 00110: val_loss improved from 0.14458 to 0.14304, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 496ms/step - loss: 0.3559 - accuracy: 0.8454 - val_loss: 0.1430 - val_accuracy: 0.9610
# Epoch 111/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3135 - accuracy: 0.8947
# Epoch 00111: val_loss improved from 0.14304 to 0.13818, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 503ms/step - loss: 0.3135 - accuracy: 0.8947 - val_loss: 0.1382 - val_accuracy: 0.9610
# Epoch 112/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3463 - accuracy: 0.8586
# Epoch 00112: val_loss improved from 0.13818 to 0.13434, saving model to ConvLSTM_model.h5
# 76/76 [==============================] - 38s 498ms/step - loss: 0.3463 - accuracy: 0.8586 - val_loss: 0.1343 - val_accuracy: 0.9610
# Epoch 113/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3388 - accuracy: 0.8816
# Epoch 00113: val_loss did not improve from 0.13434
# 76/76 [==============================] - 37s 493ms/step - loss: 0.3388 - accuracy: 0.8816 - val_loss: 0.1374 - val_accuracy: 0.9610
# Epoch 114/1000
# 76/76 [==============================] - ETA: 0s - loss: 0.3776 - accuracy: 0.8586
# Epoch 00114: val_loss did not improve from 0.13434
# 76/76 [==============================] - 38s 499ms/step - loss: 0.3776 - accuracy: 0.8586 - val_loss: 0.1447 - val_accuracy: 0.9610
# Training finished.

# %%
#y_train = model.predict(X_train)
#y_val = model.predict(X_test)

#y_train = np.argmax(y_train, axis = 1)
#y_val = np.argmax(y_val, axis = 1)

#print("Train: "+str(y_train))
#print("Validation: "+str(y_val))
